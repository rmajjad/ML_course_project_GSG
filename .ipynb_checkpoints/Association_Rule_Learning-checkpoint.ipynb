# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
import networkx as nx
import matplotlib.pyplot as plt

# %%
# تحميل البيانات
df = pd.read_csv("Groceries_dataset.csv")

# %%
df
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %%
# تحويل البيانات إلى قائمة من القوائم
transactions = df.groupby('Member_number')['itemDescription'].apply(list)

# %%
# تحويل البيانات إلى مصفوفة (One-Hot Encoding)
from mlxtend.preprocessing import TransactionEncoder

# %%
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

# %%
# استخراج المجموعات المتكررة باستخدام Apriori
frequent_itemsets = apriori(df_encoded, min_support=0.02, use_colnames=True)

# %%
# association_rules استخراج 
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0)

# %%
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
#                antecedents                       consequents   support  \
# 0               (UHT-milk)                   (bottled water)  0.021293
# 1          (bottled water)                        (UHT-milk)  0.021293
# 2               (UHT-milk)                (other vegetables)  0.038994
# 3       (other vegetables)                        (UHT-milk)  0.038994
# 4               (UHT-milk)                      (rolls/buns)  0.031042
# ...                    ...                               ...       ...
# 2951  (yogurt, rolls/buns)                (soda, whole milk)  0.024628
# 2952                (soda)  (whole milk, yogurt, rolls/buns)  0.024628
# 2953          (whole milk)        (soda, yogurt, rolls/buns)  0.024628
# 2954              (yogurt)    (soda, whole milk, rolls/buns)  0.024628
# 2955          (rolls/buns)        (soda, whole milk, yogurt)  0.024628
#
#       confidence      lift
# 0       0.271242  1.269268
# 1       0.099640  1.269268
# 2       0.496732  1.318979
# 3       0.103542  1.318979
# 4       0.395425  1.130863
# ...          ...       ...
# 2951    0.221198  1.463889
# 2952    0.078560  1.191540
# 2953    0.053751  1.269836
# 2954    0.087035  1.335684
# 2955    0.070433  1.295035
#
# [2956 rows x 5 columns]

# %%
# إنشاء الرسم البياني للعلاقات بين المنتجات
G = nx.DiGraph()

for _, row in rules.iterrows():
    G.add_edge(", ".join(row['antecedents']), ", ".join(row['consequents']), weight=row['lift'])

plt.figure(figsize=(10, 6))
pos = nx.spring_layout(G, seed=42)
edges = G.edges(data=True)

nx.draw(G, pos, with_labels=True, node_size=3000, node_color="lightblue", edge_color="red", font_size=10)
nx.draw_networkx_edge_labels(G, pos, edge_labels={(u, v): f"{d['weight']:.2f}" for u, v, d in edges})

plt.title("Network Graph of Association Rules")
plt.show()

# %%
print("edge numbers:", len(G.edges()))
print("nodes numbers:", len(G.nodes()))
print("edges:", list(G.edges(data=True)))
# Out:
# edge numbers: 2956
# nodes numbers: 298
# edges: [('UHT-milk', 'bottled water', {'weight': 1.2692684917104098}), ('UHT-milk', 'other vegetables', {'weight': 1.318979181136578}), ('UHT-milk', 'rolls/buns', {'weight': 1.1308628122317648}), ('UHT-milk', 'root vegetables', {'weight': 1.161915563407417}), ('UHT-milk', 'soda', {'weight': 1.1154060096488132}), ('UHT-milk', 'tropical fruit', {'weight': 1.174576526549149}), ('UHT-milk', 'whole milk', {'weight': 1.1269276654297404}), ('UHT-milk', 'yogurt', {'weight': 1.0509602450832252}), ('UHT-milk', 'whole milk, other vegetables', {'weight': 1.4685205628274545}), ('bottled water', 'UHT-milk', {'weight': 1.2692684917104098}), ('bottled water', 'beef', {'weight': 1.0142202803868328}), ('bottled water', 'bottled beer', {'weight': 1.1868773357485158}), ('bottled water', 'brown bread', {'weight': 1.306720424018664}), ('bottled water', 'butter', {'weight': 1.2244459649985757}), ('bottled water', 'canned beer', {'weight': 1.1190041233884858}), ('bottled water', 'chicken', {'weight': 1.1579305191464342}), ('bottled water', 'chocolate', {'weight': 1.3607959504276488}), ('bottled water', 'citrus fruit', {'weight': 1.1391245294798416}), ('bottled water', 'coffee', {'weight': 1.0654154518950436}), ('bottled water', 'cream cheese ', {'weight': 1.0850949075282288}), ('bottled water', 'curd', {'weight': 1.2816387701577447}), ('bottled water', 'dessert', {'weight': 1.1386251830108898}), ('bottled water', 'domestic eggs', {'weight': 1.081958795078725}), ('bottled water', 'frankfurter', {'weight': 1.2833625987708515}), ('bottled water', 'frozen vegetables', {'weight': 1.2166626650660264}), ('bottled water', 'fruit/vegetable juice', {'weight': 1.008921022207651}), ('bottled water', 'hamburger meat', {'weight': 1.1661303499035398}), ('bottled water', 'margarine', {'weight': 1.1390819485689012}), ('bottled water', 'napkins', {'weight': 1.2104627339894947}), ('bottled water', 'newspapers', {'weight': 1.1247904666453736}), ('bottled water', 'other vegetables', {'weight': 1.1666802960966403}), ('bottled water', 'pastry', {'weight': 1.1495812197711455}), ('bottled water', 'pip fruit', {'weight': 1.1118143498000705}), ('bottled water', 'rolls/buns', {'weight': 1.0608633768988154}), ('bottled water', 'root vegetables', {'weight': 1.0982964932357815}), ('bottled water', 'sausage', {'weight': 1.1188774388958571}), ('bottled water', 'shopping bags', {'weight': 1.1698679471788715}), ('bottled water', 'soda', {'weight': 1.1373184298269226}), ('bottled water', 'sugar', {'weight': 1.4202287919058674}), ('bottled water', 'tropical fruit', {'weight': 1.1300590488665279}), ('bottled water', 'whipped/sour cream', {'weight': 1.0709238919448376}), ('bottled water', 'white bread', {'weight': 1.1225322498941772}), ('bottled water', 'whole milk', {'weight': 1.1475972247801696}), ('bottled water', 'yogurt', {'weight': 1.09880615890962}), ('bottled water', 'bottled beer, whole milk', {'weight': 1.2647221050582396}), ('bottled water', 'whole milk, brown bread', {'weight': 1.5655585763717252}), ('bottled water', 'whole milk, canned beer', {'weight': 1.25244686109738}), ('bottled water', 'citrus fruit, other vegetables', {'weight': 1.2705850552141384}), ('bottled water', 'citrus fruit, whole milk', {'weight': 1.1958650126717354}), ('bottled water', 'whole milk, curd', {'weight': 1.4717693529024514}), ('bottled water', 'frankfurter, whole milk', {'weight': 1.4479874968855464}), ('bottled water', 'other vegetables, pastry', {'weight': 1.308239424802179}), ('bottled water', 'other vegetables, pip fruit', {'weight': 1.393885213659932}), ('bottled water', 'other vegetables, rolls/buns', {'weight': 1.1698679471788715}), ('bottled water', 'other vegetables, root vegetables', {'weight': 1.287811037221428}), ('bottled water', 'other vegetables, sausage', {'weight': 1.2926717648385324}), ('bottled water', 'other vegetables, shopping bags', {'weight': 1.2806975421747646}), ('bottled water', 'soda, other vegetables', {'weight': 1.3825712103023027}), ('bottled water', 'other vegetables ...

# %%
# إنشاء المخطط الشبكي
G = nx.DiGraph()

# إضافة  (العناصر)
for _, row in top_rules.iterrows():
    for item in row['antecedents']:
        G.add_node(item, color='blue', size=500)
    for item in row['consequents']:
        G.add_node(item, color='red', size=500)

# إضافة الحواف (العلاقات بين العناصر)
for _, row in top_rules.iterrows():
    for ante in row['antecedents']:
        for conseq in row['consequents']:
            G.add_edge(ante, conseq, weight=row['lift'])

# رسم المخطط
plt.figure(figsize=(12, 8))
pos = nx.spring_layout(G, k=0.5)  # تحسين توزيع العقد
# رسم العقد
node_colors = ['blue' if G.nodes[node]['color'] == 'blue' else 'red' for node in G.nodes()]
node_sizes = [G.nodes[node]['size'] for node in G.nodes()]
nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=node_sizes, alpha=0.8)

# رسم الحواف
edges = G.edges(data=True)
weights = [edge[2]['weight'] * 2 for edge in edges]  # مضاعفة سماكة الحواف بناءً على قوة العلاقة
nx.draw_networkx_edges(G, pos, edgelist=edges, width=weights, alpha=0.6, edge_color='gray')

# رسم التسميات
nx.draw_networkx_labels(G, pos, font_size=10, font_family="Arial")

plt.title("Network Graph of Association Rules (Enhanced)")
plt.show()
