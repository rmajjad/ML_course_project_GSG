# %%
pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-0.3.9-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: packaging in c:\users\msys\appdata\roaming\python\python312\site-packages (from kagglehub) (24.0)
# Requirement already satisfied: pyyaml in c:\wpy64-31220\python-3.12.2.amd64\lib\site-packages (from kagglehub) (6.0.1)
# Requirement already satisfied: requests in c:\wpy64-31220\python-3.12.2.amd64\lib\site-packages (from kagglehub) (2.31.0)
# Requirement already satisfied: tqdm in c:\wpy64-31220\python-3.12.2.amd64\lib\site-packages (from kagglehub) (4.65.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\wpy64-31220\python-3.12.2.amd64\lib\site-packages (from requests->kagglehub) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\wpy64-31220\python-3.12.2.amd64\lib\site-packages (from requests->kagglehub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\wpy64-31220\python-3.12.2.amd64\lib\site-packages (from requests->kagglehub) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\wpy64-31220\python-3.12.2.amd64\lib\site-packages (from requests->kagglehub) (2023.11.17)
# Requirement already satisfied: colorama in c:\users\msys\appdata\roaming\python\python312\site-packages (from tqdm->kagglehub) (0.4.6)
# Downloading kagglehub-0.3.9-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#    -------------------------- ------------- 41.0/62.7 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 62.7/62.7 kB 1.6 MB/s eta 0:00:00
# Installing collected packages: kagglehub
# Successfully installed kagglehub-0.3.9
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("zalando-research/fashionmnist")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/zalando-research/fashionmnist?dataset_version_number=4...
# 100%|█████████████████████████████████████████████████████████████████████████████| 68.8M/68.8M [00:05<00:00, 13.0MB/s]
# Extracting files...
# Path to dataset files: C:\Users\Msys\.cache\kagglehub\datasets\zalando-research\fashionmnist\versions\4

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from tensorflow.keras.datasets import fashion_mnist
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
# 1️. تحميل بيانات Fashion MNIST
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# %%
# 2️. عرض بعض الصور للتحقق من البيانات
fig, axes = plt.subplots(1, 10, figsize=(10, 3))
for i, ax in enumerate(axes):
    ax.imshow(X_train[i], cmap='magma')  # عرض الصورة باللون الاسود والوردي
    ax.axis("off")  # إخفاء المحاور
plt.show()

# %%
# 3️. تحويل الصور من شكل (28x28) إلى متجهات ذات 784 قيمة لكل صورة
X_train_flattened = X_train.reshape(len(X_train), -1)

# %%
# 4️. تقليل الأبعاد باستخدام PCA للحفاظ على المعلومات المهمة فقط
pca = PCA(n_components=50)  # نحدد عدد الأبعاد الجديدة بـ 50
X_train_pca = pca.fit_transform(X_train_flattened)

# %%
# 5️. تطبيق خوارزمية K-Means لتجميع الصور في 10 مجموعات (تمثل الفئات)
kmeans = KMeans(n_clusters=10, random_state=42, n_init=10)
clusters = kmeans.fit_predict(X_train_pca)

# %%
# 6️. تحليل جودة التجميع عبر مقارنة المجموعات بالفئات الأصلية
# إنشاء DataFrame لتوضيح العلاقة بين التجمعات والفئات الأصلية
df = pd.DataFrame({"Cluster": clusters, "True Label": y_train})

# %%
df
# Out:
#        Cluster  True Label
# 0            9           9
# 1            3           0
# 2            7           0
# 3            1           3
# 4            4           0
# ...        ...         ...
# 59995        7           5
# 59996        4           1
# 59997        3           3
# 59998        7           0
# 59999        7           5
#
# [60000 rows x 2 columns]

# %%
# Create a heatmap to show the alignment of clusters with true categories
plt.figure(figsize=(10, 6))
sns.heatmap(pd.crosstab(df["Cluster"], df["True Label"]), annot=True, fmt="d", cmap="Blues")
plt.xlabel("True Labels")
plt.ylabel("Clusters")
plt.title("Cluster Matching with True Categories ")
plt.show()

# %% [markdown]
# ### True Labels:
# #### 0 = T-shirt/top
# #### 1 = Trouser
# #### 2 = Pullover
# #### 3 = Dress
# #### 4 = Coat
# #### 5 = Sandal
# #### 6 = Shirt
# #### 7 = Sneaker
# #### 8 = Bag
# #### 9 = Ankle boot

# %%
# I tried to use Agglomerative Clustering 
# لم تكن جيدة لأنها ذو تطبيق هرمي يأهذ وقت طويلل جدا
